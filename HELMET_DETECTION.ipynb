# %%
# !pip install ultralytics roboflow

# %%
from ultralytics import YOLO
from roboflow import Roboflow
from IPython.display import Image

# %%
# Replace 'YOUR_API_KEY' with your actual Roboflow API key
try:
    rf = Roboflow(api_key="IfJKWUCU6O1vO5iVGtCi")
    # Using a well-known public dataset from Roboflow Universe
    # Source: https://universe.roboflow.com/joseph-nelson/hard-hat-workers
    project = rf.workspace("joseph-nelson").project("hard-hat-workers")
    version = project.version(1)
    dataset = version.download("yolov8")
except Exception as e:
    print(f"Error downloading dataset: {e}")
    print("Please verify your API key and that you have access to the public dataset.")

# %%
# !yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=25 imgsz=640

# %%
# Validate the model
# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml

# %%
# Run inference on test images
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt source={dataset.location}/test/images

# %%
import glob
from IPython.display import Image, display

# Ensure HOME is defined if running cells out of order
if 'HOME' not in locals():
    import os
    HOME = os.getcwd()

for image_path in glob.glob(f'{HOME}/runs/detect/predict/*.jpg')[:3]:
    display(Image(filename=image_path, height=600))
